# %% [markdown]
# # Skill-test launcher
#
# Submits the workloads in `skill-tests/workloads/`. Cluster must be running. Spark UI: http://localhost:4040

# %%
import os
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name in {"notebooks", "skill-tests"} else Path.cwd()
sys.path.insert(0, str(ROOT / "skill-tests"))
os.chdir(ROOT)
print(ROOT)

# %%
# %run skill-tests/launch.py

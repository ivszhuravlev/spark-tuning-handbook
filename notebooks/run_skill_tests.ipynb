# %% [markdown]
# # Run skill-test jobs
#
# Submits `skill-tests/workloads/` on the live cluster. Spark UI: http://localhost:4040
#
# Read `../skill-tests/TASK.md` (inside Docker: `/skill-tests/TASK.md`) before changing the jobs.

# %%
import runpy
from pathlib import Path

candidates = [Path("/skill-tests/launch.py"), Path.cwd().parent / "skill-tests" / "launch.py"]
script = next(p for p in candidates if p.exists())
print("running", script)
runpy.run_path(str(script), run_name="__main__")
